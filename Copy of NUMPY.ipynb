# %% [markdown]
# #BASIC OPERATIONS OF NUMPY

# %%
# !pip install numpy

import numpy as np

# Create a NumPy array
arr = np.array([[1, 2, 3], [4, 5, 6]])

# Perform a basic operation, e.g., sum of elements
total_sum = np.sum(arr)

print("Array:")
print(arr)
print("Sum of elements:", total_sum)
# Out:
# ...
# Array:
# [[1 2 3]
#  [4 5 6]]
# Sum of elements: 21
